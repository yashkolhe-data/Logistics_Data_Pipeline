# %%
import pandas as pd
import os

# %%
silver_path = r"C:\Users\yashk\OneDrive\Desktop\Logistics_Data_Pipeline\Silver"

# %%
gold_dataframes = {}
for folder in os.listdir(silver_path):
    folder_path = os.path.join(silver_path, folder)
    if os.path.isdir(folder_path):
        file = os.listdir(folder_path)[0]
        file_path = os.path.join(folder_path, file)
        df = pd.read_csv(file_path)
        gold_dataframes[folder] = df
print(gold_dataframes.keys())
# Out:
# dict_keys(['customers', 'delivery_events', 'drivers', 'driver_monthly_metrics', 'facilities', 'fuel_purchases', 'loads', 'maintenance_records', 'routes', 'safety_incidents', 'trailers', 'trips', 'trucks', 'truck_utilization _metrics'])

# %%
drivers = gold_dataframes["drivers"]
driver_metrics = gold_dataframes["driver_monthly_metrics"]
drivers.head()
# Out:
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 0  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 1  DRV00002    William     Martin  2020-10-02              NaN    DL128955006
# 2  DRV00003    Charles  Hernandez  2021-09-21              NaN    DL523076025
# 3  DRV00004    Barbara      Brown  2013-09-08              NaN    DL735540030
# 4  DRV00005       Mary   Martinez  2018-12-02              NaN    DL706011277
#
#   license_state date_of_birth   home_terminal employment_status cdl_class  \
# 0            WA    1973-11-07          Denver            Active         A
# 1            GA    1976-11-03        Columbus            Active         A
# 2            NC    1970-04-06  Salt Lake City            Active         A
# 3            WA    1995-02-06          Denver            Active         A
# 4            AZ    1960-07-15         Chicago            Active         A
#
#    years_experience
# 0                 3
# 1                20
# 2                19
# 3                19
# 4                12

# %%
print(drivers.columns.tolist())
print(driver_metrics.columns.tolist())
# Out:
# ['driver_id', 'first_name', 'last_name', 'hire_date', 'termination_date', 'license_number', 'license_state', 'date_of_birth', 'home_terminal', 'employment_status', 'cdl_class', 'years_experience']
# ['driver_id', 'month', 'trips_completed', 'total_miles', 'total_revenue', 'average_mpg', 'total_fuel_gallons', 'on_time_delivery_rate', 'average_idle_hours']

# %%
drivers.head()
# Out:
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 0  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 1  DRV00002    William     Martin  2020-10-02              NaN    DL128955006
# 2  DRV00003    Charles  Hernandez  2021-09-21              NaN    DL523076025
# 3  DRV00004    Barbara      Brown  2013-09-08              NaN    DL735540030
# 4  DRV00005       Mary   Martinez  2018-12-02              NaN    DL706011277
#
#   license_state date_of_birth   home_terminal employment_status cdl_class  \
# 0            WA    1973-11-07          Denver            Active         A
# 1            GA    1976-11-03        Columbus            Active         A
# 2            NC    1970-04-06  Salt Lake City            Active         A
# 3            WA    1995-02-06          Denver            Active         A
# 4            AZ    1960-07-15         Chicago            Active         A
#
#    years_experience
# 0                 3
# 1                20
# 2                19
# 3                19
# 4                12

# %%
driver_metrics.head()
# Out:
#   driver_id       month  trips_completed  total_miles  total_revenue  \
# 0  DRV00001  2022-01-01               26        36620       79141.59
# 1  DRV00001  2022-02-01                9        13515       27133.87
# 2  DRV00001  2022-03-01               20        30361       62399.62
# 3  DRV00001  2022-04-01               19        28127       68161.13
# 4  DRV00001  2022-05-01               14        16071       36256.82
#
#    average_mpg  total_fuel_gallons  on_time_delivery_rate  average_idle_hours
# 0         6.61              5574.7                  0.385                 8.2
# 1         6.69              2095.1                  0.333                 6.8
# 2         6.36              4792.2                  0.550                 7.5
# 3         6.61              4251.4                  0.474                 8.4
# 4         6.35              2573.1                  0.214                 6.8

# %%
print(drivers.columns.tolist())
# Out:
# ['driver_id', 'first_name', 'last_name', 'hire_date', 'termination_date', 'license_number', 'license_state', 'date_of_birth', 'home_terminal', 'employment_status', 'cdl_class', 'years_experience']

# %%
print(driver_metrics.columns.tolist())
# Out:
# ['driver_id', 'month', 'trips_completed', 'total_miles', 'total_revenue', 'average_mpg', 'total_fuel_gallons', 'on_time_delivery_rate', 'average_idle_hours']

# %%
driver_performance = pd.merge(
    drivers,
    driver_metrics,
    on="driver_id",
    how="left"
)
driver_performance.head()
# Out:
#   driver_id first_name  last_name   hire_date termination_date license_number  \
# 0  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 1  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 2  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 3  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
# 4  DRV00001   Jennifer  Hernandez  2014-10-31              NaN    DL673510887
#
#   license_state date_of_birth home_terminal employment_status cdl_class  \
# 0            WA    1973-11-07        Denver            Active         A
# 1            WA    1973-11-07        Denver            Active         A
# 2            WA    1973-11-07        Denver            Active         A
# 3            WA    1973-11-07        Denver            Active         A
# 4            WA    1973-11-07        Denver            Active         A
#
#    years_experience       month  trips_completed  total_miles  total_revenue  \
# 0                 3  2022-01-01             26.0      36620.0       79141.59
# 1                 3  2022-02-01              9.0      13515.0       27133.87
# 2                 3  2022-03-01             20.0      30361.0       62399.62
# 3                 3  2022-04-01             19.0      28127.0       68161.13
# 4                 3  2022-05-01             14.0      16071.0       36256.82
#
#    average_mpg  total_fuel_gallons  on_time_delivery_rate  average_idle_hours
# 0         6.61              5574.7                  0.385                 8.2
# 1         6.69              2095.1                  0.333                 6.8
# 2         6.36              4792.2                  0.550                 7.5
# 3         6.61              4251.4                  0.474                 8.4
# 4         6.35              2573.1                  0.214                 6.8

# %%
driver_performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4490 entries, 0 to 4489
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   driver_id              4490 non-null   object
#  1   first_name             4490 non-null   object
#  2   last_name              4490 non-null   object
#  3   hire_date              4490 non-null   object
#  4   termination_date       26 non-null     object
#  5   license_number         4490 non-null   object
#  6   license_state          4490 non-null   object
#  7   date_of_birth          4490 non-null   object
#  8   home_terminal          4490 non-null   object
#  9   employment_status      4490 non-null   object
#  10  cdl_class              4490 non-null   object
#  11  years_experience       4490 non-null   int64
#  12  month                  4464 non-null   object
#  13  trips_completed        4464 non-null   float64
#  14  total_miles            4464 non-null   float64
#  15  total_revenue          4464 non-null   float64
#  16  average_mpg            4464 non-null   float64
#  17  total_fuel_gallons     4464 non-null   float64
#  18  on_time_delivery_rate  4464 non-null   float64
#  19  average_idle_hours     4464 non-null   float64
# dtypes: float64(7), int64(1), object(12)
# memory usage: 701.7+ KB

# %%
driver_summary = driver_performance.groupby(
    ["driver_id", "first_name", "last_name"]
).agg({
    "trips_completed": "sum",
    "total_miles": "sum",
    "total_revenue": "sum",
    "total_fuel_gallons": "sum",
    "average_mpg": "mean",
    "on_time_delivery_rate": "mean",
    "average_idle_hours": "mean"
}).reset_index()

driver_summary.head()
# Out:
#   driver_id first_name  last_name  trips_completed  total_miles  \
# 0  DRV00001   Jennifer  Hernandez            632.0     930236.0
# 1  DRV00002    William     Martin            662.0     943246.0
# 2  DRV00003    Charles  Hernandez            677.0    1010235.0
# 3  DRV00004    Barbara      Brown            659.0     982625.0
# 4  DRV00005       Mary   Martinez            643.0     923128.0
#
#    total_revenue  total_fuel_gallons  average_mpg  on_time_delivery_rate  \
# 0     1985683.26            144705.9     6.484722               0.454167
# 1     2073621.50            146600.7     6.505000               0.468389
# 2     2146977.47            155897.8     6.539444               0.450806
# 3     2119361.45            152143.0     6.517222               0.428333
# 4     2022357.46            143472.8     6.512222               0.454056
#
#    average_idle_hours
# 0            7.036111
# 1            7.108333
# 2            6.797222
# 3            7.002778
# 4            7.136111

# %%
driver_summary = driver_performance.groupby(
    ["driver_id", "first_name", "last_name"]
).agg({
    "trips_completed": "sum",
    "total_miles": "sum",
    "total_revenue": "sum",
    "total_fuel_gallons": "sum",
    "average_mpg": "mean",
    "on_time_delivery_rate": "mean",
    "average_idle_hours": "mean"
}).reset_index()
driver_summary.head()
# Out:
#   driver_id first_name  last_name  trips_completed  total_miles  \
# 0  DRV00001   Jennifer  Hernandez            632.0     930236.0
# 1  DRV00002    William     Martin            662.0     943246.0
# 2  DRV00003    Charles  Hernandez            677.0    1010235.0
# 3  DRV00004    Barbara      Brown            659.0     982625.0
# 4  DRV00005       Mary   Martinez            643.0     923128.0
#
#    total_revenue  total_fuel_gallons  average_mpg  on_time_delivery_rate  \
# 0     1985683.26            144705.9     6.484722               0.454167
# 1     2073621.50            146600.7     6.505000               0.468389
# 2     2146977.47            155897.8     6.539444               0.450806
# 3     2119361.45            152143.0     6.517222               0.428333
# 4     2022357.46            143472.8     6.512222               0.454056
#
#    average_idle_hours
# 0            7.036111
# 1            7.108333
# 2            6.797222
# 3            7.002778
# 4            7.136111

# %%
driver_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   driver_id              150 non-null    object
#  1   first_name             150 non-null    object
#  2   last_name              150 non-null    object
#  3   trips_completed        150 non-null    float64
#  4   total_miles            150 non-null    float64
#  5   total_revenue          150 non-null    float64
#  6   total_fuel_gallons     150 non-null    float64
#  7   average_mpg            124 non-null    float64
#  8   on_time_delivery_rate  124 non-null    float64
#  9   average_idle_hours     124 non-null    float64
# dtypes: float64(7), object(3)
# memory usage: 11.8+ KB

# %%
gold_path = r"C:\Users\yashk\OneDrive\Desktop\Logistics_Data_Pipeline\Gold"

# %%
import os

driver_summary_folder = os.path.join(gold_path, "driver_performance_summary")
os.makedirs(driver_summary_folder, exist_ok=True)

driver_summary.to_csv(
    os.path.join(driver_summary_folder, "driver_performance_summary.csv"),
    index=False
)

print("✅ Driver Performance Summary saved successfully!")
# Out:
# ✅ Driver Performance Summary saved successfully!

# %%
import pandas as pd

customers = pd.read_csv("../Silver/customers/customers.csv")
customers.head()
# Out:
#   customer_id          customer_name customer_type  credit_terms_days  \
# 0   CUST00001        Metro Wholesale     Dedicated                 60
# 1   CUST00002        National Retail      Contract                 30
# 2   CUST00003         XYZ Industries      Contract                 30
# 3   CUST00004          American Corp      Contract                 15
# 4   CUST00005  American Distribution          Spot                 45
#
#   primary_freight_type account_status contract_start_date  \
# 0              General       Inactive          2020-02-20
# 1               Retail         Active          2021-06-02
# 2       Consumer Goods         Active          2020-09-04
# 3        Food/Beverage         Active          2020-11-29
# 4       Consumer Goods         Active          2020-02-04
#
#    annual_revenue_potential
# 0                    985117
# 1                   4936566
# 2                   3102814
# 3                   3948027
# 4                   3682564

# %%
customer_summary = customers.groupby(
    ["customer_id", "customer_name", "customer_type"],
    as_index=False
).agg(
    annual_revenue=("annual_revenue_potential", "sum")
)

customer_summary.head()
# Out:
#   customer_id          customer_name customer_type  annual_revenue
# 0   CUST00001        Metro Wholesale     Dedicated          985117
# 1   CUST00002        National Retail      Contract         4936566
# 2   CUST00003         XYZ Industries      Contract         3102814
# 3   CUST00004          American Corp      Contract         3948027
# 4   CUST00005  American Distribution          Spot         3682564

# %%
customer_summary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     200 non-null    object
#  1   customer_name   200 non-null    object
#  2   customer_type   200 non-null    object
#  3   annual_revenue  200 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 6.4+ KB

# %%
import os

gold_path = r"C:\Users\yashk\OneDrive\Desktop\Logistics_Data_Pipeline\Gold\customer_revenue_summary"

os.makedirs(gold_path, exist_ok=True)

customer_summary.to_csv(
    os.path.join(gold_path, "customer_revenue_summary.csv"),
    index=False
)

print("✅ Customer Revenue Summary saved successfully!")
# Out:
# ✅ Customer Revenue Summary saved successfully!

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\yashk\OneDrive\Desktop\Logistics_Data_Pipeline\Notebooks

# %%
os.listdir("../silver")
# Out:
# ['customers',
#  'delivery_events',
#  'drivers',
#  'driver_monthly_metrics',
#  'facilities',
#  'fuel_purchases',
#  'loads',
#  'maintenance_records',
#  'routes',
#  'safety_incidents',
#  'trailers',
#  'trips',
#  'trucks',
#  'truck_utilization _metrics']

# %%
import os
for item in os.listdir("../Silver"):
    print(item)
# Out:
# customers
# delivery_events
# drivers
# driver_monthly_metrics
# facilities
# fuel_purchases
# loads
# maintenance_records
# routes
# safety_incidents
# trailers
# trips
# trucks
# truck_utilization _metrics

# %%
import glob
print(glob.glob("../Silver/*"))
# Out:
# ['../Silver\\customers', '../Silver\\delivery_events', '../Silver\\drivers', '../Silver\\driver_monthly_metrics', '../Silver\\facilities', '../Silver\\fuel_purchases', '../Silver\\loads', '../Silver\\maintenance_records', '../Silver\\routes', '../Silver\\safety_incidents', '../Silver\\trailers', '../Silver\\trips', '../Silver\\trucks', '../Silver\\truck_utilization _metrics']

# %%
print(glob.glob("../Silver/truck*"))
# Out:
# ['../Silver\\trucks', '../Silver\\truck_utilization _metrics']

# %%
import os

print(os.listdir("../Silver\\truck_utilization _metrics"))
# Out:
# ['truck_utilization _metrics.csv']

# %%
truck_metrics = pd.read_csv("../Silver\\truck_utilization _metrics/truck_utilization _metrics.csv")

# %%
truck_metrics.head()
# Out:
#    truck_id       month  trips_completed  total_miles  total_revenue  \
# 0  TRK00001  2022-01-01               22        39269       84792.02
# 1  TRK00001  2022-02-01               27        40787       88809.05
# 2  TRK00001  2022-03-01               34        57422      120453.71
# 3  TRK00001  2022-04-01               20        34428       73531.28
# 4  TRK00001  2022-05-01               16        20851       40791.53
#
#    average_mpg  maintenance_events  maintenance_cost  downtime_hours  \
# 0         6.78                   2           4380.98            63.1
# 1         6.23                   0              0.00             0.0
# 2         6.49                   0              0.00             0.0
# 3         6.50                   2           3548.15            71.8
# 4         6.38                   1           1969.42            43.9
#
#    utilization_rate
# 0             0.710
# 1             0.964
# 2             1.097
# 3             0.667
# 4             0.516

# %%
print(truck_metrics.columns.tolist())
# Out:
# ['truck_id', 'month', 'trips_completed', 'total_miles', 'total_revenue', 'average_mpg', 'maintenance_events', 'maintenance_cost', 'downtime_hours', 'utilization_rate']

# %%
truck_summary = truck_metrics.groupby("truck_id").agg({
    "trips_completed": "sum",
    "total_miles": "sum",
    "total_revenue": "sum",
    "average_mpg": "mean",
    "maintenance_events": "sum",
    "maintenance_cost": "sum",
    "downtime_hours": "sum",
    "utilization_rate": "mean"
}).reset_index()

truck_summary.head()
# Out:
#    truck_id  trips_completed  total_miles  total_revenue  average_mpg  \
# 0  TRK00001              951      1356397     2896338.17     6.488611
# 1  TRK00002              887      1270572     2712361.86     6.492500
# 2  TRK00004              929      1309547     2803602.13     6.498611
# 3  TRK00006              878      1278551     2778546.55     6.485556
# 4  TRK00007              922      1336736     2887748.17     6.485833
#
#    maintenance_events  maintenance_cost  downtime_hours  utilization_rate
# 0                  24          51775.99           713.2          0.867139
# 1                  27          54869.04           665.3          0.809583
# 2                  22          38561.82           483.2          0.847111
# 3                  26          50780.83           587.7          0.801778
# 4                  20          25868.97           415.7          0.841528

# %%
print(truck_metrics.columns.tolist())
# Out:
# ['truck_id', 'month', 'trips_completed', 'total_miles', 'total_revenue', 'average_mpg', 'maintenance_events', 'maintenance_cost', 'downtime_hours', 'utilization_rate']

# %%
import os

gold_path = "../Gold/truck_summary"
os.makedirs(gold_path, exist_ok=True)

# %%
truck_summary.to_csv(
    "../Gold/truck_summary/truck_summary.csv",
    index=False
)

print("✅ Truck Summary saved successfully!")
# Out:
# ✅ Truck Summary saved successfully!

# %%
import os

print(os.listdir("../Gold/truck_summary"))
# Out:
# ['truck_summary.csv']

# %%
routes = pd.read_csv("../Silver/routes/routes.csv")
loads = pd.read_csv("../Silver/loads/loads.csv")

# %%
route_summary = loads.merge(routes, on="route_id", how="left")

# %%
print(loads.columns.tolist())
# Out:
# ['load_id', 'customer_id', 'route_id', 'load_date', 'load_type', 'weight_lbs', 'pieces', 'revenue', 'fuel_surcharge', 'accessorial_charges', 'load_status', 'booking_type']

# %%
print(routes.columns.tolist())
# Out:
# ['route_id', 'origin_city', 'origin_state', 'destination_city', 'destination_state', 'typical_distance_miles', 'base_rate_per_mile', 'fuel_surcharge_rate', 'typical_transit_days']

# %%
route_summary = loads.merge(routes, on="route_id", how="left")

route_summary = route_summary.groupby("route_id").agg({
    "load_id": "count",
    "revenue": "sum",
    "typical_distance_miles": "mean"
}).reset_index()

route_summary.rename(columns={
    "load_id": "total_loads",
    "revenue": "total_revenue",
    "typical_distance_miles": "average_distance"
}, inplace=True)

route_summary.head()
# Out:
#    route_id  total_loads  total_revenue  average_distance
# 0  RTE00001         1456     1675362.80             677.0
# 1  RTE00002         1481     2154291.12             697.0
# 2  RTE00003         1496     7621380.80            2003.0
# 3  RTE00004         1459     5418160.40            2017.0
# 4  RTE00005         1479     6236094.68            1749.0

# %%
import os

os.makedirs("../Gold/route_summary", exist_ok=True)

route_summary.to_csv(
    "../Gold/route_summary/route_summary.csv",
    index=False
)

print("✅ Route Summary saved successfully!")
# Out:
# ✅ Route Summary saved successfully!

# %%
import os

gold_path = "../Gold"

for root, dirs, files in os.walk(gold_path):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# ../Gold\customer_revenue_summary\customer_revenue_summary.csv
# ../Gold\driver_performance_summary\driver_performance_summary.csv
# ../Gold\route_summary\route_summary.csv
# ../Gold\truck_summary\truck_summary.csv

# %%
import pandas as pd

customer_summary = pd.read_csv(
    "../Gold/customer_revenue_summary/customer_revenue_summary.csv"
)

driver_summary = pd.read_csv(
    "../Gold/driver_performance_summary/driver_performance_summary.csv"
)

route_summary = pd.read_csv(
    "../Gold/route_summary/route_summary.csv"
)

truck_summary = pd.read_csv(
    "../Gold/truck_summary/truck_summary.csv"
)

print("Customer Summary:", customer_summary.shape)
print("Driver Summary:", driver_summary.shape)
print("Route Summary:", route_summary.shape)
print("Truck Summary:", truck_summary.shape)
# Out:
# Customer Summary: (200, 4)
# Driver Summary: (150, 10)
# Route Summary: (58, 4)
# Truck Summary: (92, 9)

# %%
# Gold Layer Data Quality Validation

print("=== Gold Layer Data Quality Check ===")

# 1. Duplicate check
print("\nDuplicate Records:")
print("Customer Summary:", customer_summary.duplicated().sum())
print("Driver Summary:", driver_summary.duplicated().sum())
print("Route Summary:", route_summary.duplicated().sum())
print("Truck Summary:", truck_summary.duplicated().sum())

# 2. Null check
print("\nNull Values:")
print("Customer Summary:")
print(customer_summary.isnull().sum())

print("\nDriver Summary:")
print(driver_summary.isnull().sum())

print("\nRoute Summary:")
print(route_summary.isnull().sum())

print("\nTruck Summary:")
print(truck_summary.isnull().sum())
# Out:
# === Gold Layer Data Quality Check ===
#
# Duplicate Records:
# Customer Summary: 0
# Driver Summary: 0
# Route Summary: 0
# Truck Summary: 0
#
# Null Values:
# Customer Summary:
# customer_id       0
# customer_name     0
# customer_type     0
# annual_revenue    0
# dtype: int64
#
# Driver Summary:
# driver_id                 0
# first_name                0
# last_name                 0
# trips_completed           0
# total_miles               0
# total_revenue             0
# total_fuel_gallons        0
# average_mpg              26
# on_time_delivery_rate    26
# average_idle_hours       26
# dtype: int64
#
# Route Summary:
# route_id            0
# total_loads         0
# total_revenue       0
# average_distance    0
# dtype: int64
#
# Truck Summary:
# truck_id              0
# trips_completed       0
# total_miles           0
# total_revenue         0
# average_mpg           0
# maintenance_events    0
# maintenance_cost      0
# downtime_hours        0
# utilization_rate      0
# dtype: int64

# %%
# Replace missing driver performance metrics with 0

driver_summary["average_mpg"] = driver_summary["average_mpg"].fillna(0)

driver_summary["on_time_delivery_rate"] = driver_summary["on_time_delivery_rate"].fillna(0)

driver_summary["average_idle_hours"] = driver_summary["average_idle_hours"].fillna(0)

print("Missing values replaced with 0 successfully!")
# Out:
# Missing values replaced with 0 successfully!

# %%
print(driver_summary[[
    "average_mpg",
    "on_time_delivery_rate",
    "average_idle_hours"
]].isnull().sum())
# Out:
# average_mpg              0
# on_time_delivery_rate    0
# average_idle_hours       0
# dtype: int64

# %%
# Gold Layer Business Validation Checks

print("=== Gold Layer Business Validation ===")

# Customer Revenue Validation
print("\nCustomer Revenue:")
print("Minimum Revenue:", customer_summary["annual_revenue"].min())
print("Maximum Revenue:", customer_summary["annual_revenue"].max())

# Driver Performance Validation
print("\nDriver Performance:")
print("Minimum Trips:", driver_summary["trips_completed"].min())
print("Maximum Trips:", driver_summary["trips_completed"].max())

print("Minimum Total Miles:", driver_summary["total_miles"].min())
print("Maximum Total Miles:", driver_summary["total_miles"].max())

# Route Validation
print("\nRoute Performance:")
print("Minimum Loads:", route_summary["total_loads"].min())
print("Maximum Loads:", route_summary["total_loads"].max())

print("Minimum Revenue:", route_summary["total_revenue"].min())
print("Maximum Revenue:", route_summary["total_revenue"].max())

# Truck Validation
print("\nTruck Performance:")
print("Minimum Trips:", truck_summary["trips_completed"].min())
print("Maximum Trips:", truck_summary["trips_completed"].max())

print("Minimum Revenue:", truck_summary["total_revenue"].min())
print("Maximum Revenue:", truck_summary["total_revenue"].max())
# Out:
# === Gold Layer Business Validation ===
#
# Customer Revenue:
# Minimum Revenue: 101641
# Maximum Revenue: 4990599
#
# Driver Performance:
# Minimum Trips: 0.0
# Maximum Trips: 749.0
# Minimum Total Miles: 0.0
# Maximum Total Miles: 1074677.0
#
# Route Performance:
# Minimum Loads: 1386
# Maximum Loads: 1628
# Minimum Revenue: 217573.05
# Maximum Revenue: 10069054.22
#
# Truck Performance:
# Minimum Trips: 831
# Maximum Trips: 977
# Minimum Revenue: 2532045.68
# Maximum Revenue: 3045707.57

# %%
# Save updated Driver Summary after null handling

driver_summary.to_csv(
    "../Gold/driver_performance_summary/driver_performance_summary.csv",
    index=False
)

print("✅ Updated Driver Performance Summary saved successfully!")
# Out:
# ✅ Updated Driver Performance Summary saved successfully!

# %%
# Final Gold Layer Data Quality Check

print("=== FINAL GOLD LAYER DATA QUALITY CHECK ===")

gold_tables = {
    "Customer Summary": customer_summary,
    "Driver Summary": driver_summary,
    "Route Summary": route_summary,
    "Truck Summary": truck_summary
}

for name, df in gold_tables.items():

    print(f"\n{name}")
    print("-" * 40)

    print("Rows:", len(df))
    print("Columns:", len(df))
    print("Duplicate Rows:", df.duplicated().sum())
    print("Total Null Values:", df.isnull().sum().sum())

print("\n✅ Final Gold Layer Data Quality Check Completed!")
# Out:
# === FINAL GOLD LAYER DATA QUALITY CHECK ===
#
# Customer Summary
# ----------------------------------------
# Rows: 200
# Columns: 200
# Duplicate Rows: 0
# Total Null Values: 0
#
# Driver Summary
# ----------------------------------------
# Rows: 150
# Columns: 150
# Duplicate Rows: 0
# Total Null Values: 0
#
# Route Summary
# ----------------------------------------
# Rows: 58
# Columns: 58
# Duplicate Rows: 0
# Total Null Values: 0
#
# Truck Summary
# ----------------------------------------
# Rows: 92
# Columns: 92
# Duplicate Rows: 0
# Total Null Values: 0
#
# ✅ Final Gold Layer Data Quality Check Completed!
